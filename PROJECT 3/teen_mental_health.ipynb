# %% [markdown]
# ## Teen Mental Health Project

# %% [markdown]
# #### Importing the required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# #### Ignoring all the Errors

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Importing data

# %%
data = pd.read_csv("Teen_Mental_Health_Dataset.csv")
data.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...

# %% [markdown]
# #### To find whether addiction to Social Media gives Depression or not

# %%
# Count the number of missing values in each column
missing_values = data.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# No missing values found in the dataset. We can proceed with our analysis without needing to handle missing data.
# Check for duplicate rows
duplicate_rows = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")
# No duplicate rows found in the dataset. We can proceed with our analysis without needing to handle duplicates.
# Out:
# Missing values in each column:
# age                         0
# gender                      0
# daily_social_media_hours    0
# platform_usage              0
# sleep_hours                 0
# screen_time_before_sleep    0
# academic_performance        0
# physical_activity           0
# social_interaction_level    0
# stress_level                0
# anxiety_level               0
# addiction_level             0
# depression_label            0
# dtype: int64
# Number of duplicate rows: 0

# %%
# Get data types of each column
data_types = data.dtypes
print("Data types of each column:")
print(data_types)
print()
# Get summary statistics for numerical columns
numerical_summary = data.describe()
print("Summary statistics for numerical columns:")
print(numerical_summary)
print()
# Get summary statistics for categorical columns
categorical_summary = data.describe(include=["object"])
print("Summary statistics for categorical columns:")
print(categorical_summary)
# Out:
# Data types of each column:
# age                           int64
# gender                       object
# daily_social_media_hours    float64
# platform_usage               object
# sleep_hours                 float64
# screen_time_before_sleep    float64
# academic_performance        float64
# physical_activity           float64
# social_interaction_level     object
# stress_level                  int64
# anxiety_level                 int64
# addiction_level               int64
# depression_label              int64
# dtype: object
#
# Summary statistics for numerical columns:
#                age  daily_social_media_hours  sleep_hours  \
# count  1200.000000               1200.000000  1200.000000
# mean     15.928333                  4.536667     6.449417
# std       2.021947                  2.029599     1.442677
# min      13.000000                  1.000000     4.000000
# 25%      14.000000                  2.800000     5.200000
# ...

# %% [markdown]
# #### Data Types (Input)
# ###### gender, platform_usage, social_interaction_level - Object
# ###### age, stress_level, anxiety_level, addiction_level - Int
# ###### daily_social_media_hours, sleep_hours, screen_time_before_sleep, academic_performance, physical_activity - Float
#
# #### Data Types (Output)
# ###### depression_label - Int
